# %%
# %cd yolov5
# Out:
# C:\Users\Irvin\Python\watermeter\yolov5

# %%
# !python detect.py --weights ./runs/train/yolov5x_results_350/weights/best.pt \
                  --img 608 \
                  --conf 0.4 \
                  --source ./Jeans-v2-1/test/images \
                  --name yolov5x_results_350 \
                  --save-txt
# Out:
# detect: weights=['./runs/train/yolov5x_results_350/weights/best.pt'], source=./Jeans-v2-1/test/images, data=data\coco128.yaml, imgsz=[608, 608], conf_thres=0.4, iou_thres=0, max_det=1000, device=, view_img=False, save_txt=True, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs\detect, name=yolov5x_results_350, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5  2022-1-11 torch 1.10.1 CUDA:0 (NVIDIA GeForce RTX 3060, 12288MiB)
#
# Fusing layers...
# Model Summary: 444 layers, 86180143 parameters, 0 gradients, 204.0 GFLOPs
# image 1/37 C:\Users\Irvin\Python\watermeter\yolov5\Jeans-v2-1\test\images\IMG_20200902_132013_jpg.rf.8cb3fcc6f1732fd003fa004d606f059a.jpg: 608x608 1 Broken Filaments, Done. (0.041s)
# ...

# %%
# !python detect.py --weights ./runs/train/yolov5l_results_350/weights/best.pt \
                  --img 608 \
                  --conf 0.4 \
                  --source ./Jeans-v2-1/test/images \
                  --name yolov5l_results_350 \
                  --save-txt
# Out:
# detect: weights=['./runs/train/yolov5l_results_350/weights/best.pt'], source=./Jeans-v2-1/test/images, data=data\coco128.yaml, imgsz=[608, 608], conf_thres=0.4, iou_thres=0, max_det=1000, device=, view_img=False, save_txt=True, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs\detect, name=yolov5l_results_350, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5  2022-1-11 torch 1.10.1 CUDA:0 (NVIDIA GeForce RTX 3060, 12288MiB)
#
# Fusing layers...
# Model Summary: 367 layers, 46113663 parameters, 0 gradients, 107.8 GFLOPs
# image 1/37 C:\Users\Irvin\Python\watermeter\yolov5\Jeans-v2-1\test\images\IMG_20200902_132013_jpg.rf.8cb3fcc6f1732fd003fa004d606f059a.jpg: 608x608 1 Broken Filaments, Done. (0.022s)
# ...

# %%
# !python detect.py --weights ./runs/train/yolov5m_results_250/weights/best.pt \
                  --img 608 \
                  --conf 0.4 \
                  --source ./Jeans-v2-1/test/images \
                  --name yolov5m_results_250 \
                  --save-txt
# Out:
# detect: weights=['./runs/train/yolov5m_results_250/weights/best.pt'], source=./Jeans-v2-1/test/images, data=data\coco128.yaml, imgsz=[608, 608], conf_thres=0.4, iou_thres=0, max_det=1000, device=, view_img=False, save_txt=True, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs\detect, name=yolov5m_results_250, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5  2022-1-11 torch 1.10.1 CUDA:0 (NVIDIA GeForce RTX 3060, 12288MiB)
#
# Fusing layers...
# Model Summary: 290 layers, 20856975 parameters, 0 gradients, 48.0 GFLOPs
# image 1/37 C:\Users\Irvin\Python\watermeter\yolov5\Jeans-v2-1\test\images\IMG_20200902_132013_jpg.rf.8cb3fcc6f1732fd003fa004d606f059a.jpg: 608x608 1 Broken Filaments, Done. (0.015s)
# ...

# %%
# !python detect.py --weights ./runs/train/yolov5s_results_250/weights/best.pt \
                  --img 608 \
                  --conf 0.4 \
                  --source ./Jeans-v2-1/test/images \
                  --name yolov5s_results_250 \
                  --save-txt
# Out:
# detect: weights=['./runs/train/yolov5s_results_250/weights/best.pt'], source=./Jeans-v2-1/test/images, data=data\coco128.yaml, imgsz=[608, 608], conf_thres=0.4, iou_thres=0, max_det=1000, device=, view_img=False, save_txt=True, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs\detect, name=yolov5s_results_250, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5  2022-1-11 torch 1.10.1 CUDA:0 (NVIDIA GeForce RTX 3060, 12288MiB)
#
# Fusing layers...
# Model Summary: 213 layers, 7015519 parameters, 0 gradients, 15.8 GFLOPs
# image 1/37 C:\Users\Irvin\Python\watermeter\yolov5\Jeans-v2-1\test\images\IMG_20200902_132013_jpg.rf.8cb3fcc6f1732fd003fa004d606f059a.jpg: 608x608 1 Broken Filaments, Done. (0.015s)
# ...

# %%
# !python detect.py --weights ./runs/train/yolov5n_results_300/weights/best.pt \
                  --img 608 \
                  --conf 0.4 \
                  --source ./Jeans-v2-1/test/images \
                  --name yolov5n_results_300 \
                  --save-txt
# Out:
# detect: weights=['./runs/train/yolov5n_results_300/weights/best.pt'], source=./Jeans-v2-1/test/images, data=data\coco128.yaml, imgsz=[608, 608], conf_thres=0.4, iou_thres=0, max_det=1000, device=, view_img=False, save_txt=True, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs\detect, name=yolov5n_results_300, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5  2022-1-11 torch 1.10.1 CUDA:0 (NVIDIA GeForce RTX 3060, 12288MiB)
#
# Fusing layers...
# Model Summary: 213 layers, 1761871 parameters, 0 gradients, 4.2 GFLOPs
# image 1/37 C:\Users\Irvin\Python\watermeter\yolov5\Jeans-v2-1\test\images\IMG_20200902_132013_jpg.rf.8cb3fcc6f1732fd003fa004d606f059a.jpg: 608x608 Done. (0.010s)
# ...

# %%
# %cd yolov5
# Out:
# [WinError 2] The system cannot find the file specified: 'yolov5'
# C:\Users\Irvin\Python\watermeter\yolov5

# %%
# !python detect.py --weights ./runs/train/yolov5x_results_new/weights/best.pt \
                  --img 608 \
                  --conf 0.4 \
                  --source ./Jeans-v2-1/test/images \
                  --name yolov5x_results_new \
                  --save-txt

# !python detect.py --weights ./runs/train/yolov5l_results_new/weights/best.pt \
                  --img 608 \
                  --conf 0.4 \
                  --source ./Jeans-v2-1/test/images \
                  --name yolov5l_results_new \
                  --save-txt

# !python detect.py --weights ./runs/train/yolov5m_results_new/weights/best.pt \
                  --img 608 \
                  --conf 0.4 \
                  --source ./Jeans-v2-1/test/images \
                  --name yolov5m_results_new \
                  --save-txt

# !python detect.py --weights ./runs/train/yolov5s_results_new/weights/best.pt \
                  --img 608 \
                  --conf 0.4 \
                  --source ./Jeans-v2-1/test/images \
                  --name yolov5s_results_new \
                  --save-txt

# !python detect.py --weights ./runs/train/yolov5n_results_new/weights/best.pt \
                  --img 608 \
                  --conf 0.4 \
                  --source ./Jeans-v2-1/test/images \
                  --name yolov5n_results_new\
                  --save-txt
# Out:
# detect: weights=['./runs/train/yolov5x_results_new/weights/best.pt'], source=./Jeans-v2-1/test/images, data=data\coco128.yaml, imgsz=[608, 608], conf_thres=0.4, iou_thres=0, max_det=1000, device=, view_img=False, save_txt=True, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs\detect, name=yolov5x_results_new, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5  2022-1-11 torch 1.10.1 CUDA:0 (NVIDIA GeForce RTX 3060, 12288MiB)
#
# Fusing layers...
# Model Summary: 356 layers, 78794202 parameters, 0 gradients, 167.5 GFLOPs
# image 1/37 C:\Users\Irvin\Python\watermeter\yolov5\Jeans-v2-1\test\images\IMG_20200902_132013_jpg.rf.8cb3fcc6f1732fd003fa004d606f059a.jpg: 608x608 1 Broken Filaments, Done. (0.033s)
# ...

# %%
# !python detect.py --weights ./runs/train/yolov5x_results_new/weights/best.pt \
                  --img 608 \
                  --conf 0.4 \
                  --source ./Jeans-v2-1/test/images \
                  --name yolov5x_results_new \
                  --save-txt
# Out:
# python: can't open file 'C:\Users\Irvin\Python\watermeter\detect.py': [Errno 2] No such file or directory
